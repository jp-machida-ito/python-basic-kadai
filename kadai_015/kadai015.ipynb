# %%
#課題
class Human:

#初期化
  def __init__(self):
    self.name =""
    self.age =""

#メソッドの設定
  def printinfo(self,name,age):
    self.name = name
    self.age = age

#インスタンス
user = Human()

user.printinfo("侍太郎",30)

print(user.name)
print(user.age)
# Out:
# 侍太郎
# 30
