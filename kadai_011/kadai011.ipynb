# %%
#課題011

array = ["水","金","地","火","木","土","天","海","冥"]

#for構文
for planet in array:
  print(planet)

#while構文
i = 0

while i < 9:

  print(array[i])

  i =i + 1
# Out:
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
